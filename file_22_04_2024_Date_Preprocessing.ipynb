# %%
#1st step
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import dataset
df = pd.read_csv("flights.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              336776 non-null  int64
#  1   year            336776 non-null  int64
#  2   month           336776 non-null  int64
#  3   day             336776 non-null  int64
#  4   dep_time        328521 non-null  float64
#  5   sched_dep_time  336776 non-null  int64
#  6   dep_delay       328521 non-null  float64
#  7   arr_time        328063 non-null  float64
#  8   sched_arr_time  336776 non-null  int64
#  9   arr_delay       327346 non-null  float64
#  10  carrier         336776 non-null  object
#  11  flight          336776 non-null  int64
#  12  tailnum         334264 non-null  object
#  13  origin          336776 non-null  object
#  14  dest            336776 non-null  object
#  15  air_time        327346 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# name                 0
# dtype: int64

# %%
df.describe().T
#this is summary of continuous data only
# Out:
#                    count           mean           std     min       25%  \
# id              336776.0  168387.500000  97219.001466     0.0  84193.75
# year            336776.0    2013.000000      0.000000  2013.0   2013.00
# month           336776.0       6.548510      3.414457     1.0      4.00
# day             336776.0      15.710787      8.768607     1.0      8.00
# dep_time        328521.0    1349.109947    488.281791     1.0    907.00
# sched_dep_time  336776.0    1344.254840    467.335756   106.0    906.00
# dep_delay       328521.0      12.639070     40.210061   -43.0     -5.00
# arr_time        328063.0    1502.054999    533.264132     1.0   1104.00
# sched_arr_time  336776.0    1536.380220    497.457142     1.0   1124.00
# arr_delay       327346.0       6.895377     44.633292   -86.0    -17.00
# flight          336776.0    1971.923620   1632.471938     1.0    553.00
# air_time        327346.0     150.686460     93.688305    20.0     82.00
# ...

# %%
df.describe(include="object")
# Out:
#        carrier tailnum  origin    dest            time_hour  \
# count   336776  334264  336776  336776               336776
# unique      16    4043       3     105                 6936
# top         UA  N725MQ     EWR     ORD  2013-09-13 08:00:00
# freq     58665     575  120835   17283                   94
#
#                          name
# count                  336776
# unique                     16
# top     United Air Lines Inc.
# freq                    58665

# %%
#EDA
#univariate
#bivariate
#multivariate

# %%
df['month'].value_counts()
# Out:
# 7     29425
# 8     29327
# 10    28889
# 3     28834
# 5     28796
# 4     28330
# 6     28243
# 12    28135
# 9     27574
# 11    27268
# 1     27004
# 2     24951
# Name: month, dtype: int64

# %%
sns.countplot(x=df['month'])
plt.show()

# %%
sns.countplot(x=df['day'])
plt.show()

# %%
sns.distplot(df['dep_time'])
plt.show()
# Out:
# Running cells with 'Python 3.12.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/ankit/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
df.isnull().sum()
# Out:
# id                   0
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# name                 0
# dtype: int64

# %%
#in dept time column around 2 percent data
(8255/336776)*100
# Out:
# 2.451184169893341

# %%
df.dropna(subset=['dep_time'],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                   0
# year                 0
# month                0
# day                  0
# dep_time             0
# sched_dep_time       0
# dep_delay            0
# arr_time           458
# sched_arr_time       0
# arr_delay         1175
# carrier              0
# flight               0
# tailnum              0
# origin               0
# dest                 0
# air_time          1175
# distance             0
# hour                 0
# minute               0
# time_hour            0
# name                 0
# dtype: int64

# %%
df.shape
# Out:
# (328521, 21)

# %%
(458/328521)*100
# Out:
# 0.13941270116674429

# %%
#as we got to know less than 1% of the data is missing in other columns,
#so we decided to delete the missing values from the given dataset
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id                0
# year              0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         0
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          0
# distance          0
# hour              0
# minute            0
# time_hour         0
# name              0
# dtype: int64

# %%
#univariate analysis
plt.hist(x = df['dep_delay'],bins=30)
plt.show()

# %%
#bivariate
data = df.groupby('month')['dep_delay'].mean()
plt.plot(data.index,data.values)
plt.show()

# %%
#feature scaling

# %%
df.describe()
# Out:
#                   id      year          month            day       dep_time  \
# count  327346.000000  327346.0  327346.000000  327346.000000  327346.000000
# mean   168190.637793    2013.0       6.564803      15.740825    1348.789883
# std     97510.314383       0.0       3.413444       8.777376     488.319979
# min         0.000000    2013.0       1.000000       1.000000       1.000000
# 25%     83007.250000    2013.0       4.000000       8.000000     907.000000
# 50%    168251.500000    2013.0       7.000000      16.000000    1400.000000
# 75%    252782.750000    2013.0      10.000000      23.000000    1744.000000
# max    336769.000000    2013.0      12.000000      31.000000    2400.000000
#
#        sched_dep_time      dep_delay       arr_time  sched_arr_time  \
# count   327346.000000  327346.000000  327346.000000   327346.000000
# mean      1340.335098      12.555156    1501.908238     1532.788426
# std        467.413156      40.065688     532.888731      497.979124
# ...

# %%
sns.distplot(df['dep_time'])
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9288\1634027735.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['dep_time'])

# %%
df.replace('UA','0',inplace=True)

# %%
df.describe()
# Out:
#                   id      year          month            day       dep_time  \
# count  327346.000000  327346.0  327346.000000  327346.000000  327346.000000
# mean   168190.637793    2013.0       6.564803      15.740825    1348.789883
# std     97510.314383       0.0       3.413444       8.777376     488.319979
# min         0.000000    2013.0       1.000000       1.000000       1.000000
# 25%     83007.250000    2013.0       4.000000       8.000000     907.000000
# 50%    168251.500000    2013.0       7.000000      16.000000    1400.000000
# 75%    252782.750000    2013.0      10.000000      23.000000    1744.000000
# max    336769.000000    2013.0      12.000000      31.000000    2400.000000
#
#        sched_dep_time      dep_delay       arr_time  sched_arr_time  \
# count   327346.000000  327346.000000  327346.000000   327346.000000
# mean      1340.335098      12.555156    1501.908238     1532.788426
# std        467.413156      40.065688     532.888731      497.979124
# ...

# %%
df.describe(include='object')
# Out:
#        carrier tailnum  origin    dest            time_hour  \
# count   327346  327346  327346  327346               327346
# unique      16    4037       3     104                 6922
# top          0  N725MQ     EWR     ATL  2013-09-20 08:00:00
# freq     57782     544  117127   16837                   94
#
#                          name
# count                  327346
# unique                     16
# top     United Air Lines Inc.
# freq                    57782

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 327346 entries, 0 to 336769
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            327346 non-null  int64
#  1   month           327346 non-null  int64
#  2   day             327346 non-null  int64
#  3   sched_dep_time  327346 non-null  int64
#  4   sched_arr_time  327346 non-null  int64
#  5   carrier         327346 non-null  object
#  6   flight          327346 non-null  int64
#  7   tailnum         327346 non-null  object
#  8   origin          327346 non-null  object
#  9   dest            327346 non-null  object
#  10  distance        327346 non-null  int64
#  11  hour            327346 non-null  int64
#  12  minute          327346 non-null  int64
#  13  time_hour       327346 non-null  object
#  14  name            327346 non-null  object
# dtypes: int64(9), object(6)
# memory usage: 40.0+ MB

# %%
df.drop(['dep_delay','dep_time','arr_time','arr_delay','air_time'],axis=1,inplace=True)

# %%
df.drop(['id'],axis=1,inplace=True)

# %%
df.drop(['carrier','tailnum','dest','time_hour','name'],axis=1,inplace=True)

# %%
df
# Out:
#         year  month  day  sched_dep_time  sched_arr_time  flight  distance  \
# 0       2013      1    1             515             819    1545      1400
# 1       2013      1    1             529             830    1714      1416
# 2       2013      1    1             540             850    1141      1089
# 3       2013      1    1             545            1022     725      1576
# 4       2013      1    1             600             837     461       762
# ...      ...    ...  ...             ...             ...     ...       ...
# 336765  2013      9   30            2245            2351    1816       209
# 336766  2013      9   30            2250               7    2002       301
# 336767  2013      9   30            2246               1     486       264
# 336768  2013      9   30            2255            2358     718       187
# 336769  2013      9   30            2359             350     745      1617
#
#         hour  minute
# 0          5      15
# 1          5      29
# ...

# %%
sns.distplot(df['sched_arr_time'])
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9288\2835082505.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sched_arr_time'])

# %%
df.drop(['origin'],axis=1,inplace=True)

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_new = sc.fit_transform(df)

# %%
df_new_data = pd.DataFrame(df_new)
df_new_data
# Out:
#           0         1         2         3         4         5         6  \
# 0       0.0 -1.630263 -1.679414 -1.765753 -1.433372 -0.245513  0.477816
# 1       0.0 -1.630263 -1.679414 -1.735801 -1.411283 -0.141290  0.499558
# 2       0.0 -1.630263 -1.679414 -1.712267 -1.371121 -0.494662  0.055209
# 3       0.0 -1.630263 -1.679414 -1.701570 -1.025724 -0.751211  0.716977
# 4       0.0 -1.630263 -1.679414 -1.583901 -1.397226 -0.914021 -0.389140
# ...     ...       ...       ...       ...       ...       ...       ...
# 327341  0.0  0.713415  1.624540  1.935475  1.643067 -0.078386 -1.140594
# 327342  0.0  0.713415  1.624540  1.946172 -3.063965  0.036321 -1.015578
# 327343  0.0  0.713415  1.624540  1.937614 -3.076014 -0.898603 -1.065856
# 327344  0.0  0.713415  1.624540  1.956869  1.657123 -0.755528 -1.170489
# 327345  0.0  0.713415  1.624540  2.179371 -2.375180 -0.738877  0.772691
#
#                7         8
# 0      -1.746227 -0.582203
# 1      -1.746227  0.143341
# ...

# %%
sns.displot(df_new_data[3])
plt.show()

# %%
sns.countplot(x = df['month'])
plt.show()

# %%
sns.distplot(df['month'])
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9288\559358544.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['month'])

# %%
sns.distplot(df_new_data[1])
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9288\3230529367.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_new_data[1])

# %%
df
# Out:
#         year  month  day  sched_dep_time  sched_arr_time  flight  distance  \
# 0       2013      1    1             515             819    1545      1400
# 1       2013      1    1             529             830    1714      1416
# 2       2013      1    1             540             850    1141      1089
# 3       2013      1    1             545            1022     725      1576
# 4       2013      1    1             600             837     461       762
# ...      ...    ...  ...             ...             ...     ...       ...
# 336765  2013      9   30            2245            2351    1816       209
# 336766  2013      9   30            2250               7    2002       301
# 336767  2013      9   30            2246               1     486       264
# 336768  2013      9   30            2255            2358     718       187
# 336769  2013      9   30            2359             350     745      1617
#
#         hour  minute
# 0          5      15
# 1          5      29
# ...

# %%
df_new_data
# Out:
#           0         1         2         3         4         5         6  \
# 0       0.0 -1.630263 -1.679414 -1.765753 -1.433372 -0.245513  0.477816
# 1       0.0 -1.630263 -1.679414 -1.735801 -1.411283 -0.141290  0.499558
# 2       0.0 -1.630263 -1.679414 -1.712267 -1.371121 -0.494662  0.055209
# 3       0.0 -1.630263 -1.679414 -1.701570 -1.025724 -0.751211  0.716977
# 4       0.0 -1.630263 -1.679414 -1.583901 -1.397226 -0.914021 -0.389140
# ...     ...       ...       ...       ...       ...       ...       ...
# 327341  0.0  0.713415  1.624540  1.935475  1.643067 -0.078386 -1.140594
# 327342  0.0  0.713415  1.624540  1.946172 -3.063965  0.036321 -1.015578
# 327343  0.0  0.713415  1.624540  1.937614 -3.076014 -0.898603 -1.065856
# 327344  0.0  0.713415  1.624540  1.956869  1.657123 -0.755528 -1.170489
# 327345  0.0  0.713415  1.624540  2.179371 -2.375180 -0.738877  0.772691
#
#                7         8
# 0      -1.746227 -0.582203
# 1      -1.746227  0.143341
# ...
